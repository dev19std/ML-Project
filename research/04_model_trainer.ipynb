# %%
import os

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project\\research'

# %%
os.chdir("../")

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen =True)
class ModelTrainerConfig:
    root_dir : Path
    trin_data_path :Path
    test_data_path : Path
    alpha: str
    l1_ratio : float
    target_column : str

# %%
from ML_project.constants import *
from ML_project.utils.common import read_yaml , create_directories

# %%
class ConfigurationManager:

    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
        schema_filepath=SCHEMA_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_model_trainer_config(self) -> ModelTrainerConfig:

        config = self.config.model_trainer
        params = self.params.ElasticNet
        schema = self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir=config.root_dir,
            train_data_path=config.train_data_path,
            test_data_path=config.test_data_path,
            model_name=config.model_name,
            alpha=params.alpha,
            l1_ratio=params.l1_ratio,
            target_column=schema.name
        )

        return model_trainer_config

# %%
from ML_project.entity.congif_entity import ModelTrainerConfig

# %%
config = ConfigurationManager()

model_trainer_config = config.get_model_trainer_config()

print(model_trainer_config)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 config = ConfigurationManager()
#       2
#       3 model_trainer_config = config.get_model_trainer_config()
#       4
#
# Cell In[6], line 10, in ConfigurationManager.__init__(self, config_filepath, params_filepath, schema_filepath)
#       6         params_filepath=PARAMS_FILE_PATH,
#       7         schema_filepath=SCHEMA_FILE_PATH
#       8     ):
#       9
# ---> 10         self.config = read_yaml(config_filepath)
#      11         self.params = read_yaml(params_filepath)
#      12         self.schema = read_yaml(schema_filepath)
#      13
#
# File ~\.conda\envs\myproject\Lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File D:\e drive\ML_Project\src\ML_project\utils\common.py:36, in read_yaml(path_to_yaml)
#      34     raise ValueError("yaml file is empty")
#      35 except Exception as e:
# ---> 36     raise e
#
# File D:\e drive\ML_Project\src\ML_project\utils\common.py:29, in read_yaml(path_to_yaml)
#      16 """reads yaml file and returns
#      17
#      18 Args:
#    (...)     26     ConfigBox: ConfigBox type
#      27 """
#      28 try:
# ---> 29     with open(path_to_yaml) as yaml_file:
#      30         content = yaml.safe_load(yaml_file)
#      31         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
import os
print(os.getcwd())
# Out:
# d:\e drive\ML_Project\research

# %%
import os
os.chdir(r"D:\e drive\ML_Project")
print(os.getcwd())
# Out:
# D:\e drive\ML_Project

# %%
config = ConfigurationManager()
model_trainer_config = config.get_model_trainer_config()
print(model_trainer_config)
# Out:
# [2026-09-05 09:12:05,249: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:12:05,253: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:12:05,256: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:12:05,258: INFO : common : created directory at: artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'ElasticNet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ElasticNet'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'ElasticNet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/config_box.py:29, in box.config_box.ConfigBox.__getattr__()
# ---> 29 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'ElasticNet'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'elasticnet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'elasticnet'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'elasticnet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 config = ConfigurationManager()
# ----> 2 model_trainer_config = config.get_model_trainer_config()
#       3 print(model_trainer_config)
#
# Cell In[6], line 19, in ConfigurationManager.get_model_trainer_config(self)
#      16     def get_model_trainer_config(self) -> ModelTrainerConfig:
#      17
#      18         config = self.config.model_trainer
# ---> 19         params = self.params.ElasticNet
#      20         schema = self.schema.TARGET_COLUMN
#      21
#      22         create_directories([config.root_dir])
#
# File box/config_box.py:31, in box.config_box.ConfigBox.__getattr__()
# ---> 31 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'elasticnet'"

# %%
config = ConfigurationManager()
model_trainer_config = config.get_model_trainer_config()
print(model_trainer_config)
# Out:
# [2026-09-05 09:23:17,772: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:23:17,789: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:23:17,793: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:23:17,794: INFO : common : created directory at: artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'ElasticNet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ElasticNet'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'ElasticNet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/config_box.py:29, in box.config_box.ConfigBox.__getattr__()
# ---> 29 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'ElasticNet'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'elasticnet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'elasticnet'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'elasticnet'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 config = ConfigurationManager()
# ----> 2 model_trainer_config = config.get_model_trainer_config()
#       3 print(model_trainer_config)
#
# Cell In[6], line 19, in ConfigurationManager.get_model_trainer_config(self)
#      16     def get_model_trainer_config(self) -> ModelTrainerConfig:
#      17
#      18         config = self.config.model_trainer
# ---> 19         params = self.params.ElasticNet
#      20         schema = self.schema.TARGET_COLUMN
#      21
#      22         create_directories([config.root_dir])
#
# File box/config_box.py:31, in box.config_box.ConfigBox.__getattr__()
# ---> 31 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'elasticnet'"

# %%
config = ConfigurationManager()
print(config.params)
# Out:
# [2026-09-05 09:23:40,198: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:23:40,200: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:23:40,204: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:23:40,206: INFO : common : created directory at: artifacts]
# {'IMAGE_SIZE': [224, 224]}

# %%
IMAGE_SIZE: [224, 224]

ElasticNet:
  alpha: 0.5
  l1_ratio: 0.7
# Out:
#   Cell In[14], line 3
#     ElasticNet:
#                ^
# SyntaxError: invalid syntax

# %%
config = ConfigurationManager()
print(config.params)
# Out:
# [2026-09-05 09:25:03,109: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:25:03,112: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:25:03,115: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:25:03,117: INFO : common : created directory at: artifacts]
# {'IMAGE_SIZE': [224, 224], 'ElasticNet': {'alpha': 0.5, 'l1_ratio': 0.7}}

# %%
config = ConfigurationManager()

model_trainer_config = config.get_model_trainer_config()

print(model_trainer_config)
# Out:
# [2026-09-05 09:25:24,160: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:25:24,164: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:25:24,168: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:25:24,170: INFO : common : created directory at: artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'TARGET_COLUMN'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'TARGET_COLUMN'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'TARGET_COLUMN'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/config_box.py:29, in box.config_box.ConfigBox.__getattr__()
# ---> 29 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'TARGET_COLUMN'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'target_column'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'target_column'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'target_column'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[16], line 3
#       1 config = ConfigurationManager()
#       2
# ----> 3 model_trainer_config = config.get_model_trainer_config()
#       4
#       5 print(model_trainer_config)
#
# Cell In[6], line 20, in ConfigurationManager.get_model_trainer_config(self)
#      16     def get_model_trainer_config(self) -> ModelTrainerConfig:
#      17
#      18         config = self.config.model_trainer
#      19         params = self.params.ElasticNet
# ---> 20         schema = self.schema.TARGET_COLUMN
#      21
#      22         create_directories([config.root_dir])
#      23
#
# File box/config_box.py:31, in box.config_box.ConfigBox.__getattr__()
# ---> 31 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'target_column'"

# %%
config = ConfigurationManager()
print(config.schema)
# Out:
# [2026-09-05 09:26:16,991: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:26:16,994: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:26:16,999: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:26:17,002: INFO : common : created directory at: artifacts]
# {'COLUMNS': {'fixed acidity': 'float', 'volatile acidity': 'float', 'citric acid': 'float', 'residual sugar': 'float', 'chlorides': 'float', 'free sulfur dioxide': 'float', 'total sulfur dioxide': 'float', 'density': 'float', 'pH': 'float', 'sulphates': 'float', 'alcohol': 'float', 'quality': 'int', 'TARGET_COLUMN': {'name': 'quality'}}}

# %%
config = ConfigurationManager()
print(config.schema)
# Out:
# [2026-09-05 09:28:07,056: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:28:07,059: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:28:07,065: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:28:07,069: INFO : common : created directory at: artifacts]
# {'COLUMNS': {'fixed acidity': 'float', 'volatile acidity': 'float', 'citric acid': 'float', 'residual sugar': 'float', 'chlorides': 'float', 'free sulfur dioxide': 'float', 'total sulfur dioxide': 'float', 'density': 'float', 'pH': 'float', 'sulphates': 'float', 'alcohol': 'float', 'quality': 'int'}, 'TARGET_COLUMN': {'name': 'quality'}}

# %%
config = ConfigurationManager()

model_trainer_config = config.get_model_trainer_config()

print(model_trainer_config)
# Out:
# [2026-09-05 09:28:27,622: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-05 09:28:27,625: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-05 09:28:27,629: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-05 09:28:27,633: INFO : common : created directory at: artifacts]
# [2026-09-05 09:28:27,635: INFO : common : created directory at: artifacts/model_trainer]
# ModelTrainerConfig(root_dir='artifacts/model_trainer', train_data_path='artifacts/data_transformation/train.csv', test_data_path='artifacts/data_transformation/test.csv', model_name='model.joblib', alpha=0.5, l1_ratio=0.7, target_column='quality')

# %%
print(model_trainer_config)
# Out:
# ModelTrainerConfig(root_dir='artifacts/model_trainer', train_data_path='artifacts/data_transformation/train.csv', test_data_path='artifacts/data_transformation/test.csv', model_name='model.joblib', alpha=0.5, l1_ratio=0.7, target_column='quality')
