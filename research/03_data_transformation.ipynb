# %%
import os

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project\\research'

# %%
os.chdir("../")

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir : Path
    data_path : Path

# %%
from ML_project.constants import *
from ML_project.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transforamtion

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,

        )

        return data_transformation_config

# %%
import os 
from ML_project import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config:DataTransformationConfig):
        self.config = config

    def Train_test_split(self):
        data = pd.read_csv(self.config.data_path)

        train ,test = train_test_split(data)
        train.to_csv(os.path.join(self.config.root_dir, "tain.csv"), index= False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False) 
        logger.info("slpited data into training and testing sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.Train_test_split()
except Exception as e:
    raise e
# Out:
# [2026-08-25 23:14:55,282: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-08-25 23:14:55,285: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-08-25 23:14:55,289: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-08-25 23:14:55,291: INFO : common : created directory at: artifacts]
# [2026-08-25 23:14:55,293: INFO : common : created directory at: artifacts/data_transformation]
# [2026-08-25 23:14:55,411: INFO : 1599723036 : slpited data into training and testing sets]
# [2026-08-25 23:14:55,413: INFO : 1599723036 : (1199, 12)]
# [2026-08-25 23:14:55,415: INFO : 1599723036 : (400, 12)]
# (1199, 12)
# (400, 12)

# %%
config = ConfigurationManager()
data_transformation_config = config.get_data_transformation_config()
print(data_transformation_config)
# Out:
# [2026-08-25 23:14:57,456: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-08-25 23:14:57,461: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-08-25 23:14:57,467: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-08-25 23:14:57,469: INFO : common : created directory at: artifacts]
# [2026-08-25 23:14:57,471: INFO : common : created directory at: artifacts/data_transformation]
# DataTransformationConfig(root_dir='artifacts/data_transformation', data_path='artifacts/data_ingestion/winequality-red.csv')
