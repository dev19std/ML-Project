# %%
import os

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project\\research'

# %%
os.chdir("../")

# %%
pwd
# Out:
# 'd:\\e drive\\ML_Project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir : Path
    data_path : Path

# %%
from ML_project.constants import *
from ML_project.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transforamtion

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,

        )

        return data_transformation_config

# %%
import os 
from ML_project import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config:DataTransformationConfig):
        self.config = config

    def Train_test_split(self):
        data = pd.read_csv(self.config.data_path)

        train ,test = train_test_split(data)
        train.to_csv(os.path.join(self.config.root_dir, "tain.csv"), index= False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False) 
        logger.info("slpited data into training and testing sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.Train_test_split()
except Exception as e:
    raise e
# Out:
# [2026-09-03 13:54:26,975: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-03 13:54:26,998: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-03 13:54:27,016: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-03 13:54:27,019: INFO : common : created directory at: artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'data_transforamtion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'data_transforamtion'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'data_transforamtion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/config_box.py:29, in box.config_box.ConfigBox.__getattr__()
# ---> 29 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_transforamtion'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'data_transforamtion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'data_transforamtion'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'data_transforamtion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[10], line 7
#       3     data_transformation_config = config.get_data_transformation_config()
#       4     data_transformation = DataTransformation(config=data_transformation_config)
#       5     data_transformation.Train_test_split()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[10], line 7
#       3     data_transformation_config = config.get_data_transformation_config()
#       4     data_transformation = DataTransformation(config=data_transformation_config)
#       5     data_transformation.Train_test_split()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[7], line 15, in ConfigurationManager.get_data_transformation_config(self)
#      14     def get_data_transformation_config(self) -> DataTransformationConfig:
# ---> 15         config = self.config.data_transforamtion
#      16
#      17         create_directories([config.root_dir])
#      18
#
# File box/config_box.py:31, in box.config_box.ConfigBox.__getattr__()
# ---> 31 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_transforamtion'"

# %%
config = ConfigurationManager()
data_transformation_config = config.get_data_transformation_config()
print(data_transformation_config)
# Out:
# [2026-08-25 23:14:57,456: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-08-25 23:14:57,461: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-08-25 23:14:57,467: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-08-25 23:14:57,469: INFO : common : created directory at: artifacts]
# [2026-08-25 23:14:57,471: INFO : common : created directory at: artifacts/data_transformation]
# DataTransformationConfig(root_dir='artifacts/data_transformation', data_path='artifacts/data_ingestion/winequality-red.csv')

# %%
from ML_project.config.configuration import ConfigurationManager
from ML_project.componenet.data_transformation import DataTransformation

try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()

    data_transformation = DataTransformation(
        config=data_transformation_config
    )

    data_transformation.Train_test_split()

except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      11
#      12     data_transformation.Train_test_split()
#      13
#      14 except Exception as e:
# ---> 15     raise e
#
# Cell In[2], line 15
#      11
#      12     data_transformation.Train_test_split()
#      13
#      14 except Exception as e:
# ---> 15     raise e
#
# File D:\e drive\ML_Project\src\ML_project\config\configuration.py:24, in ConfigurationManager.__init__(self, config_filepath, params_filepath, schema_filepath)
#      18 def __init__(
#      19     self,
#      20     config_filepath=CONFIG_FILE_PATH,
#      21     params_filepath=PARAMS_FILE_PATH,
#      22     schema_filepath=SCHEMA_FILE_PATH
#      23 ):
# ---> 24     self.config = read_yaml(config_filepath)
#      25     self.params = read_yaml(params_filepath)
#      26     self.schema = read_yaml(schema_filepath)
#
# File ~\.conda\envs\myproject\Lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File D:\e drive\ML_Project\src\ML_project\utils\common.py:36, in read_yaml(path_to_yaml)
#      34     raise ValueError("yaml file is empty")
#      35 except Exception as e:
# ---> 36     raise e
#
# File D:\e drive\ML_Project\src\ML_project\utils\common.py:29, in read_yaml(path_to_yaml)
#      16 """reads yaml file and returns
#      17
#      18 Args:
#    (...)     26     ConfigBox: ConfigBox type
#      27 """
#      28 try:
# ---> 29     with open(path_to_yaml) as yaml_file:
#      30         content = yaml.safe_load(yaml_file)
#      31         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
from ML_project.config.configuration import ConfigurationManager
from ML_project.componenet.data_transformation import DataTransformation

try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()

    data_transformation = DataTransformation(
        config=data_transformation_config
    )
    print("helo")

    data_transformation.Train_test_split()

except Exception as e:
    raise e
# Out:
# [2026-09-03 13:55:51,878: INFO : common : yaml file: config\config.yaml loaded successfully]
# [2026-09-03 13:55:51,880: INFO : common : yaml file: params.yaml loaded successfully]
# [2026-09-03 13:55:51,883: INFO : common : yaml file: schema.yaml loaded successfully]
# [2026-09-03 13:55:51,884: INFO : common : created directory at: artifacts]
# [2026-09-03 13:55:51,886: INFO : common : created directory at: artifacts/data_transformation]
# helo
# [2026-09-03 13:55:51,909: INFO : data_transformation : slpited data into training and testing sets]
# [2026-09-03 13:55:51,911: INFO : data_transformation : (1199, 12)]
# [2026-09-03 13:55:51,913: INFO : data_transformation : (400, 12)]
# (1199, 12)
# (400, 12)
